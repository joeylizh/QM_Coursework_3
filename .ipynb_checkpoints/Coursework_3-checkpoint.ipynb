# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import statsmodels.formula.api as smf
import statsmodels.api as sm
import scipy.stats as sps

# %%
df_fs= pd.read_csv("Fire_statistics.csv")
df_fs.replace('\s+', '_',regex=True,inplace=True)
df_fs.head()
# Out:
#     New_code       Local_Authority  Dwelling_fires  Age_over_60  \
# 0  E09000002  Barking_and_Dagenham             157        26120
# 1  E09000003                Barnet             227        64344
# 2  E09000004                Bexley             143        50007
# 3  E09000005                 Brent             240        44944
# 4  E09000006               Bromley             167        70529
#
#    Long_term_illness  Any_neurotic_disorder  All_phobias  Depressive_episode  \
# 0             185911                  20417         2450                3958
# 1             356386                  39761         4745                7718
# 2             231997                  24735         2934                4836
# 3             311215                  37683         4497                7274
# 4             309392                  33613         3995                6604
#
#    Generalised_anxiety_disorder  Mixed_anxiety_depression  \
# 0                          5883                      9502
# 1                         11644                     18395
# 2                          7292                     11403
# 3                         10953                     17453
# 4                         10054                     15427
#
#    Obsessive_compulsive_disorder  Panic_disorder  Blind_and_partially_sighted  \
# 0                           1750             942                          810
# 1                           3348            1868                         1835
# 2                           2073            1159                          515
# 3                           3205            1752                         2310
# 4                           2797            1584                         1975
#
#    Deaf_and_hard_of_hearing  Household_of_parents_working_full_time
# 0                       600                                    5557
# 1                      1305                                    8852
# 2                      1365                                    6952
# 3                       935                                    7368
# 4                      2370                                    9209

# %%
df1 = df_fs.drop(['New_code', 'Local_Authority'],axis = 1)

df1.head()
# Out:
#    Dwelling_fires  Age_over_60  Long_term_illness  Any_neurotic_disorder  \
# 0             157        26120             185911                  20417
# 1             227        64344             356386                  39761
# 2             143        50007             231997                  24735
# 3             240        44944             311215                  37683
# 4             167        70529             309392                  33613
#
#    All_phobias  Depressive_episode  Generalised_anxiety_disorder  \
# 0         2450                3958                          5883
# 1         4745                7718                         11644
# 2         2934                4836                          7292
# 3         4497                7274                         10953
# 4         3995                6604                         10054
#
#    Mixed_anxiety_depression  Obsessive_compulsive_disorder  Panic_disorder  \
# 0                      9502                           1750             942
# 1                     18395                           3348            1868
# 2                     11403                           2073            1159
# 3                     17453                           3205            1752
# 4                     15427                           2797            1584
#
#    Blind_and_partially_sighted  Deaf_and_hard_of_hearing  \
# 0                          810                       600
# 1                         1835                      1305
# 2                          515                      1365
# 3                         2310                       935
# 4                         1975                      2370
#
#    Household_of_parents_working_full_time
# 0                                    5557
# 1                                    8852
# 2                                    6952
# 3                                    7368
# 4                                    9209

# %%
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(20,11))
plt.matshow(df_fs.corr(), fignum=f.number)
plt.xticks(range(df1.shape[1]), df1.columns, fontsize=20, rotation=45)
plt.yticks(range(df1.shape[1]), df1.columns, fontsize=20)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=30)

# plt.savefig('Correlation Matrix.png', dpi=300, bbox_inches = 'tight')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# calculating VIF
# This function is adjusted from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: (default 5) the threshould VIF value. If the VIF of a variable is greater than thresh, it should be removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        # If there are multiple variabels with VIF>thresh, only one of them is removed. This is because we want to keep as many variables as possible
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
df_predictors_selected_VIF = drop_column_using_vif_(df1.drop('Dwelling_fires', axis=1))
# Out:
# Dropping: Any_neurotic_disorder
# Dropping: Depressive_episode
# Dropping: All_phobias
# Dropping: Panic_disorder
# Dropping: Mixed_anxiety_depression
# Dropping: Obsessive_compulsive_disorder
# Dropping: Long_term_illness
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
df_predictors_selected_VIF.columns
# Out:
# Index(['Age_over_60', 'Generalised_anxiety_disorder',
#        'Blind_and_partially_sighted', 'Deaf_and_hard_of_hearing',
#        'Household_of_parents_working_full_time'],
#       dtype='object')

# %%
model_df = sm.OLS(endog=df1[['Dwelling_fires']], exog=sm.add_constant(df_predictors_selected_VIF)).fit()
model_df.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Dwelling_fires   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     21.29
# Date:                Sun, 16 Jan 2022   Prob (F-statistic):           1.92e-08
# Time:                        12:13:20   Log-Likelihood:                -152.59
# No. Observations:                  32   AIC:                             317.2
# Df Residuals:                      26   BIC:                             326.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                     22.5800     28.928      0.781      0.442     -36.883      82.043
# Age_over_60                               -0.0024      0.001     -3.395      0.002      -0.004      -0.001
# Generalised_anxiety_disorder               0.0277      0.004      6.382      0.000       0.019       0.037
# Blind_and_partially_sighted                0.0053      0.020      0.264      0.794      -0.036       0.047
# Deaf_and_hard_of_hearing                   0.0121      0.014      0.842      0.407      -0.017       0.042
# Household_of_parents_working_full_time     0.0010      0.005      0.191      0.850      -0.010       0.012
# ==============================================================================
# Omnibus:                        0.959   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.619   Jarque-Bera (JB):                0.579
# Skew:                           0.329   Prob(JB):                        0.749
# Kurtosis:                       2.963   Cond. No.                     2.20e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(model_df.fittedvalues, model_df.resid)
# adding title and labels
plt.xlabel('Fitted number of fire')
plt.ylabel('Residual')
plt.axhline(y=0, linestyle='dashed', color='r')
# draw a horizontal line
# https://pythonguides.com/matplotlib-dashed-line/
plt.title('Residual vs. Fitted number of fire')
plt.show()

# %%
# from sklearn.preprocessing import MinMaxScaler

# min_max_scaler = MinMaxScaler().fit(df_2)
# df_norm = min_max_scaler.transform(df_2)
# df_norm

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(df1)
df_std = scaler.transform(df1)

# df_std

# %%
df_std = pd.DataFrame(df_std, columns = df1.columns)
df_std.head()
# Out:
#    Dwelling_fires  Age_over_60  Long_term_illness  Any_neurotic_disorder  \
# 0       -0.788811    -1.036753          -1.271961              -1.620015
# 1        0.299874     2.056223           1.857270               1.138483
# 2       -1.006547     0.896114          -0.426008              -1.004258
# 3        0.502059     0.486431           1.028114               0.842155
# 4       -0.633284     2.556695           0.994651               0.261764
#
#    All_phobias  Depressive_episode  Generalised_anxiety_disorder  \
# 0    -1.594396           -1.644820                     -1.676206
# 1     1.098436            1.175259                      1.168003
# 2    -1.026496           -0.986301                     -0.980582
# 3     0.807446            0.842250                      0.826856
# 4     0.218426            0.339736                      0.383019
#
#    Mixed_anxiety_depression  Obsessive_compulsive_disorder  Panic_disorder  \
# 0                 -1.589372                      -1.585791       -1.666969
# 1                  1.118605                       1.077996        1.200036
# 2                 -1.010505                      -1.047366       -0.995111
# 3                  0.831760                       0.839622        0.840886
# 4                  0.214829                       0.159506        0.320738
#
#    Blind_and_partially_sighted  Deaf_and_hard_of_hearing  \
# 0                    -1.161820                 -0.358059
# 1                     1.356032                  0.972718
# 2                    -1.886470                  1.085976
# 3                     2.522841                  0.274296
# 4                     1.699934                  2.983042
#
#    Household_of_parents_working_full_time
# 0                               -0.611990
# 1                                1.102135
# 2                                0.113717
# 3                                0.330128
# 4                                1.287853

# %%
df2= pd.DataFrame(df_std)
df3=df2.drop(columns='Dwelling_fires')

df3.head()
# Out:
#    Age_over_60  Long_term_illness  Any_neurotic_disorder  All_phobias  \
# 0    -1.036753          -1.271961              -1.620015    -1.594396
# 1     2.056223           1.857270               1.138483     1.098436
# 2     0.896114          -0.426008              -1.004258    -1.026496
# 3     0.486431           1.028114               0.842155     0.807446
# 4     2.556695           0.994651               0.261764     0.218426
#
#    Depressive_episode  Generalised_anxiety_disorder  Mixed_anxiety_depression  \
# 0           -1.644820                     -1.676206                 -1.589372
# 1            1.175259                      1.168003                  1.118605
# 2           -0.986301                     -0.980582                 -1.010505
# 3            0.842250                      0.826856                  0.831760
# 4            0.339736                      0.383019                  0.214829
#
#    Obsessive_compulsive_disorder  Panic_disorder  Blind_and_partially_sighted  \
# 0                      -1.585791       -1.666969                    -1.161820
# 1                       1.077996        1.200036                     1.356032
# 2                      -1.047366       -0.995111                    -1.886470
# 3                       0.839622        0.840886                     2.522841
# 4                       0.159506        0.320738                     1.699934
#
#    Deaf_and_hard_of_hearing  Household_of_parents_working_full_time
# 0                 -0.358059                               -0.611990
# 1                  0.972718                                1.102135
# 2                  1.085976                                0.113717
# 3                  0.274296                                0.330128
# 4                  2.983042                                1.287853

# %%
extracted_col = df1["Dwelling_fires"]
df4 = df3.join(extracted_col)
df4.head()
# Out:
#    Age_over_60  Long_term_illness  Any_neurotic_disorder  All_phobias  \
# 0    -1.036753          -1.271961              -1.620015    -1.594396
# 1     2.056223           1.857270               1.138483     1.098436
# 2     0.896114          -0.426008              -1.004258    -1.026496
# 3     0.486431           1.028114               0.842155     0.807446
# 4     2.556695           0.994651               0.261764     0.218426
#
#    Depressive_episode  Generalised_anxiety_disorder  Mixed_anxiety_depression  \
# 0           -1.644820                     -1.676206                 -1.589372
# 1            1.175259                      1.168003                  1.118605
# 2           -0.986301                     -0.980582                 -1.010505
# 3            0.842250                      0.826856                  0.831760
# 4            0.339736                      0.383019                  0.214829
#
#    Obsessive_compulsive_disorder  Panic_disorder  Blind_and_partially_sighted  \
# 0                      -1.585791       -1.666969                    -1.161820
# 1                       1.077996        1.200036                     1.356032
# 2                      -1.047366       -0.995111                    -1.886470
# 3                       0.839622        0.840886                     2.522841
# 4                       0.159506        0.320738                     1.699934
#
#    Deaf_and_hard_of_hearing  Household_of_parents_working_full_time  \
# 0                 -0.358059                               -0.611990
# 1                  0.972718                                1.102135
# 2                  1.085976                                0.113717
# 3                  0.274296                                0.330128
# 4                  2.983042                                1.287853
#
#    Dwelling_fires
# 0             157
# 1             227
# 2             143
# 3             240
# 4             167

# %%
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(19, 15))
plt.matshow(df4.corr(), fignum=f.number)
plt.xticks(range(df4.shape[1]), df4.columns, fontsize=14, rotation=45)
plt.yticks(range(df4.shape[1]), df4.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df_predictors_selected_VIF = drop_column_using_vif_(df4.drop('Dwelling_fires', axis=1))
# Out:
# Dropping: Any_neurotic_disorder
# Dropping: Depressive_episode
# Dropping: All_phobias
# Dropping: Panic_disorder
# Dropping: Mixed_anxiety_depression
# Dropping: Obsessive_compulsive_disorder
# Dropping: Long_term_illness
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model_df = sm.OLS(endog=df4[['Dwelling_fires']], exog=sm.add_constant(df_predictors_selected_VIF)).fit()
model_df.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Dwelling_fires   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     21.29
# Date:                Sun, 16 Jan 2022   Prob (F-statistic):           1.92e-08
# Time:                        12:55:18   Log-Likelihood:                -152.59
# No. Observations:                  32   AIC:                             317.2
# Df Residuals:                      26   BIC:                             326.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                    207.7188      5.587     37.178      0.000     196.234     219.203
# Age_over_60                              -30.1496      8.880     -3.395      0.002     -48.404     -11.895
# Generalised_anxiety_disorder              56.0590      8.784      6.382      0.000      38.004      74.114
# Blind_and_partially_sighted                2.1726      8.220      0.264      0.794     -14.725      19.070
# Deaf_and_hard_of_hearing                   6.4230      7.624      0.842      0.407      -9.248      22.094
# Household_of_parents_working_full_time     1.9731     10.349      0.191      0.850     -19.299      23.245
# ==============================================================================
# Omnibus:                        0.959   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.619   Jarque-Bera (JB):                0.579
# Skew:                           0.329   Prob(JB):                        0.749
# Kurtosis:                       2.963   Cond. No.                         4.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.scatter(model_df.fittedvalues, model_df.resid)
# adding title and labels
plt.xlabel('Fitted life expectancy')
plt.ylabel('Residual')
plt.axhline(y=0, linestyle='dashed', color='r')
# draw a horizontal line
# https://pythonguides.com/matplotlib-dashed-line/
plt.title('Residual vs. Fitted life expectancy')
plt.show()

# %%
df5 = df4[['Dwelling_fires', 6]]
df5
# Out:
#     Dwelling_fires         6
# 0              157 -1.676206
# 1              227  1.168003
# 2              143 -0.980582
# 3              240  0.826856
# 4              167  0.383019
# 5              203  0.551371
# 6              301  1.575800
# 7              239  1.346229
# 8              238  0.556802
# 9              222 -0.187699
# 10             301  0.010275
# 11             206 -0.604876
# 12             219  0.391906
# 13             141 -1.047232
# 14             109 -0.976632
# 15             176 -0.427637
# 16             168 -0.556493
# 17             241 -0.213371
# 18             153 -0.673500
# 19              96 -1.828760
# 20             333  1.892262
# 21             230  0.927077
# 22             134 -0.880361
# 23             269  0.274405
# 24             169 -0.336303
# 25              92 -1.277296
# 26             313  1.453362
# 27             137 -1.407633
# 28             300 -0.202510
# 29             213 -0.258298
# 30             261  1.625170
# 31             249  0.552852

# %% [markdown]
# ### Cluster

# %%
import sklearn.cluster as sklc  # For clustering
import sklearn.metrics as sklm

# %%
# Cluster constituencies based on proportion of electorate voting for each political party

# Cluster repreatedly using 2-10 clusters and find which gives best sillhouette score
cluster_numbers = range(2,11,1)

all_scores = {'n':[], 'ss':[]}

for n in cluster_numbers:
    
    # Create Kmeans object
    kmeans = sklc.KMeans(n_clusters=n, n_init=10)
    
    # Run clusters
    kmeans_output = kmeans.fit(df5)
    clustering_ids_kmeans = kmeans_output.labels_
    
    # Get silhouetter score
    ss = sklm.silhouette_score(df5,clustering_ids_kmeans)
    
    all_scores['n'].append(n)
    all_scores['ss'].append(ss)
    
dfSS = pd.DataFrame(all_scores)

dfSS
# Out:
#     n        ss
# 0   2  0.625481
# 1   3  0.639180
# 2   4  0.645174
# 3   5  0.609395
# 4   6  0.615776
# 5   7  0.608720
# 6   8  0.603398
# 7   9  0.609558
# 8  10  0.628737

# %%
dfSS.set_index('n')['ss'].plot()
# Out:
# <AxesSubplot:xlabel='n'>

# %%
# Add clsuter label to data
kmeans_results = sklc.KMeans(n_clusters=4, n_init=10).fit(df5)
# set(list(kmeans_results.labels))
df5['cluster'] = kmeans_results.labels_

cluster_labels_vertical = np.array([kmeans_results.labels_]).T
complete_data_with_clusters = np.hstack((df5, cluster_labels_vertical))

# dd=kmeans_results.labels

# print(complete_data_with_clusters)
# kmeans_results
df5['cluster']
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# 0     3
# 1     0
# 2     3
# 3     0
# 4     3
# 5     0
# 6     2
# 7     0
# 8     0
# 9     0
# 10    2
# 11    0
# 12    0
# 13    3
# 14    1
# 15    3
# 16    3
# 17    0
# 18    3
# 19    1
# 20    2
# 21    0
# 22    3
# 23    2
# 24    3
# 25    1
# 26    2
# 27    3
# 28    2
# 29    0
# 30    0
# 31    0
# Name: cluster, dtype: int32

# %%
data = df5.to_numpy()
data
# Out:
# array([[ 1.57000000e+02, -1.67620634e+00,  3.00000000e+00],
#        [ 2.27000000e+02,  1.16800321e+00,  0.00000000e+00],
#        [ 1.43000000e+02, -9.80582096e-01,  3.00000000e+00],
#        [ 2.40000000e+02,  8.26856051e-01,  0.00000000e+00],
#        [ 1.67000000e+02,  3.83019150e-01,  3.00000000e+00],
#        [ 2.03000000e+02,  5.51371078e-01,  0.00000000e+00],
#        [ 3.01000000e+02,  1.57579996e+00,  2.00000000e+00],
#        [ 2.39000000e+02,  1.34622915e+00,  0.00000000e+00],
#        [ 2.38000000e+02,  5.56801785e-01,  0.00000000e+00],
#        [ 2.22000000e+02, -1.87698823e-01,  0.00000000e+00],
#        [ 3.01000000e+02,  1.02751452e-02,  2.00000000e+00],
#        [ 2.06000000e+02, -6.04875888e-01,  0.00000000e+00],
#        [ 2.19000000e+02,  3.91905762e-01,  0.00000000e+00],
#        [ 1.41000000e+02, -1.04723169e+00,  3.00000000e+00],
#        [ 1.09000000e+02, -9.76632491e-01,  1.00000000e+00],
#        [ 1.76000000e+02, -4.27637348e-01,  3.00000000e+00],
#        [ 1.68000000e+02, -5.56493222e-01,  3.00000000e+00],
#        [ 2.41000000e+02, -2.13371258e-01,  0.00000000e+00],
#        [ 1.53000000e+02, -6.73500281e-01,  3.00000000e+00],
#        [ 9.60000000e+01, -1.82875984e+00,  1.00000000e+00],
#        [ 3.33000000e+02,  1.89226209e+00,  2.00000000e+00],
#        [ 2.30000000e+02,  9.27077287e-01,  0.00000000e+00],
#        [ 1.34000000e+02, -8.80360861e-01,  3.00000000e+00],
#        [ 2.69000000e+02,  2.74405003e-01,  2.00000000e+00],
#        [ 1.69000000e+02, -3.36302724e-01,  3.00000000e+00],
#        [ 9.20000000e+01, -1.27729620e+00,  1.00000000e+00],
#        [ 3.13000000e+02,  1.45336220e+00,  2.00000000e+00],
#        [ 1.37000000e+02, -1.40763317e+00,  3.00000000e+00],
#        [ 3.00000000e+02, -2.02509843e-01,  2.00000000e+00],
#        [ 2.13000000e+02, -2.58298018e-01,  0.00000000e+00],
#        [ 2.61000000e+02,  1.62517003e+00,  0.00000000e+00],
#        [ 2.49000000e+02,  5.52852180e-01,  0.00000000e+00]])

# %%
# FIGURE PARAMETERS

# Use the next line to set figure height and width (experiment to check the scale):
figure_width, figure_height = 7,7

# These lines set the figure title and axis labels and the font sizes:
fig_title = 'Life expectancy vs. Current smoker'
x_label   = 'Current smoker'
y_label   = 'Life expectancy'
title_fontsize = 15
label_fontsize = 10

# These lines set the limits of the x and y axes, so that all plots are on the same scale.
x_min, x_max = 1.12*np.min(data[:,1]), 1.15*np.max(data[:,1])
y_min, y_max = 0.99*np.min(data[:,0]), 1.01*np.max(data[:,0])


# This is a function that sets up each figure's x-limits and y-limits and axis labels.

def setup_figure():
    
    plt.xlim([x_min, x_max])
    plt.ylim([y_min, y_max])
    plt.xlabel(x_label,fontsize=label_fontsize)
    plt.ylabel(y_label,fontsize=label_fontsize)

# %%
#Let's have a little look at our data from the off. 

#First extract the x and y values from the data:
x_values = data[:,1]
y_values = data[:,0]

#And then a cheeky plot:
plt.figure(0,figsize=(figure_width,figure_height))
setup_figure()
plt.xlabel(x_label,fontsize=label_fontsize)
plt.ylabel(y_label,fontsize=label_fontsize)
plt.title(fig_title,fontsize=title_fontsize)
plt.plot(x_values,y_values, 'k.')
